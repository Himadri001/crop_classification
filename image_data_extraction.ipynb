# %%
import os
import numpy as np
import pandas as pd
from osgeo import gdal

def read_image(file_path):
    """Read a .tif image and return its data as a numpy array."""
    ds = gdal.Open(file_path, gdal.GA_ReadOnly)
    img_data = []
    for band in range(ds.RasterCount):
        band_data = ds.GetRasterBand(band + 1).ReadAsArray()
        img_data.append(band_data)
    return np.dstack(img_data)

# def read_image(file_path):
#     """Read a .tif image and return its data as a numpy array."""
#     ds = gdal.Open(file_path, gdal.GA_ReadOnly)
#     if ds.RasterCount < 4:
#         raise ValueError(f"Image at {file_path} does not have 4 channels.")
#     img_data = []
#     for band in range(1, 5):  # Reading only the first 4 bands
#         band_data = ds.GetRasterBand(band).ReadAsArray()
#         img_data.append(band_data)
#     return np.dstack(img_data)

def process_images(folder_path, batch_size=10):
    """Process all images in the given folder and return a DataFrame."""
    batch_data = []
    batch_count = 0
    data = []
    for class_label in os.listdir(folder_path):
        class_folder = os.path.join(folder_path, class_label)
        print(f"Processing class: {class_label} in folder: {class_folder}")
#         print(os.path.isdir)
#         print(os.listdir(class_folder))
        try:
             if os.path.isdir(class_folder) and class_label in ['0','1']:
#             print("Class directory found")
                try:
                    for image_file in os.listdir(class_folder):
                        print("Inside the listdir- ", image_file)
                        if image_file.endswith('.jpg'):
                            print("Image is valid jpg")
                            image_path = os.path.join(class_folder, image_file)
                            print(f"Reading image: {image_path}")
                            image_data = read_image(image_path)
                            print("image data size - ", len(image_data))
                            if image_data.size > 0:  # Check if image data is not empty
                        # Flatten the image data and append class label
                                flat_data = image_data.reshape(-1, image_data.shape[2])
                                flat_data_with_label = np.hstack([flat_data, np.full((flat_data.shape[0], 1), class_label)])
                                batch_data.extend(flat_data_with_label)
                                print("batch data - ", len(batch_data))
#                                 print("batch size - ", len(batch_size))
                            else:
                                print(f"Warning: Empty image at {image_path}")
                            if len(batch_data) >= batch_size:
                                yield pd.DataFrame(batch_data)
                                batch_data = []  # Reset batch
                                batch_count += 1
                                print(f"Yielded a batch of size {batch_size}")
                except Exception as e:
                    print(f"Error processing directory {class_folder}: {e}")
        except Exception as e:
            print(f"Error processing directory {class_folder}: {e}")
    if batch_data:
        yield pd.DataFrame(batch_data)
        print(f"Yielded the last batch")
#     return pd.DataFrame(data)
    
# Set the folder path and process the images
# folder_path = './test/0'
folder_path = '/Users/c.himadry/Downloads/NAIP/test'
# image_data_df = process_images(folder_path)

# # Define column names (adjust according to the number of bands in your images)
# column_names = [f'Band_{i}' for i in range(image_data_df.shape[1] - 1)] + ['Class_Label']
# image_data_df.columns = column_names

# # Save the data to a CSV file
# image_data_df.to_csv('image_data.csv', index=False)
# csv_file = 'image_data.csv'
# Process images and save in batches
for i, df_batch in enumerate(process_images(folder_path)):
    if df_batch.empty:
        print(f"Batch {i} is empty.")
        continue
    if i == 0:
        # Write the first batch with headers
        print(df_batch.head())
        df_batch.to_csv('/Users/c.himadry/Downloads/NAIP/image_data.csv', mode='w', index=False)
    else:
        # Append subsequent batches without headers
        print(df_batch.head())
        df_batch.to_csv('/Users/c.himadry/Downloads/NAIP/image_data.csv', mode='a', index=False, header=False)
#         print(df_batch)

    print(f"Processed batch {i+1}")
# Out:
# Processing class: .DS_Store in folder: /Users/c.himadry/Downloads/NAIP/test/.DS_Store
# Processing class: 0 in folder: /Users/c.himadry/Downloads/NAIP/test/0
# Inside the listdir-  298911_ortho_1-1_1n_s_ia013_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0
2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/518501_ortho_1-1_1n_s_ia157_2017_1.jpg
# image data size -  240
# batch data -  57600
#      0    1   2  3
# 0   92  108  79  0
# 1   99  115  86  0
# 2  102  118  89  0
# 3   99  115  86  0
# 4   95  111  82  0
# Processed batch 113
# Yielded a batch of size 10
# Inside the listdir-  559368_ortho_1-1_1n_s_ia195_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/559368_ortho_1-1_1n_s_ia195_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  67   85  59  0
# 1  82  100  74  0
# 2  88  106  80  0
# 3  80   98  72  0
# 4  71   89  63  0
# Processed batch 114
# Yielded a batch of size 10
# Inside the listdir-  312340_ortho_1-1_1n_s_ia019_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/312340_ortho_1-1_1n_s_ia019_2017_1.jpg
# image data size -  240
# batch data -  57600
#      0    1    2  3
# 0  153  137  104  0
# 1  144  129   96  0
# 2  134  121   87  0
# 3  142  132   97  0
# 4  138  130   94  0
# Processed batch 115
# Yielded a batch of size 10
# Inside the listdir-  246567_ortho_1-1_1n_s_il141_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/246567_ortho_1-1_1n_s_il141_2017_1.jpg
# image data size -  240
# batch data -  57600
#      0    1    2  3
# 0  124  127  108  0
# 1  118  121  102  0
# 2  121  124  105  0
# 3  127  130  111  0
# 4  131  134  115  0
# Processed batch 116
# Yielded a batch of size 10
# Inside the listdir-  449414_ortho_1-1_1n_s_ia101_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/449414_ortho_1-1_1n_s_ia101_2017_1.jpg
# image data size -  240
# batch data -  57600
#      0    1    2  3
# 0  132  134   97  0
# 1  135  137  100  0
# 2  129  135   97  0
# 3  121  129   92  0
# 4  113  123   88  0
# Processed batch 117
# Yielded a batch of size 10
# Inside the listdir-  307529_ortho_1-1_1n_s_ia015_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/307529_ortho_1-1_1n_s_ia015_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  80  106  79  0
# 1  84  110  83  0
# 2  88  114  87  0
# 3  86  112  85  0
# 4  79  105  78  0
# Processed batch 118
# Yielded a batch of size 10
# Inside the listdir-  479183_ortho_1-1_1n_s_ia123_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/479183_ortho_1-1_1n_s_ia123_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0   1   2  3
# 0  81  99  85  0
# 1  81  99  85  0
# 2  81  99  85  0
# 3  79  97  83  0
# 4  77  95  81  0
# Processed batch 119
# Yielded a batch of size 10
# Inside the listdir-  130338_ortho_1-1_1n_s_il061_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/130338_ortho_1-1_1n_s_il061_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  82   97  74  0
# 1  77   92  69  0
# 2  83   98  75  0
# 3  86  101  78  0
# 4  80   95  72  0
# Processed batch 120
# Yielded a batch of size 10
# Inside the listdir-  263626_ortho_1-1_1n_s_il175_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/263626_ortho_1-1_1n_s_il175_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0   1   2  3
# 0  74  99  69  0
# 1  71  96  66  0
# 2  67  92  62  0
# 3  66  91  61  0
# 4  68  93  63  0
# Processed batch 121
# Yielded a batch of size 10
# Inside the listdir-  127800_ortho_1-1_1n_s_il059_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/127800_ortho_1-1_1n_s_il059_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0   1   2  3
# 0  65  83  67  0
# 1  58  76  60  0
# 2  56  74  58  0
# 3  60  78  62  0
# 4  63  81  65  0
# Processed batch 122
# Yielded a batch of size 10
# Inside the listdir-  326843_ortho_1-1_1n_s_ia023_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/326843_ortho_1-1_1n_s_ia023_2017_1.jpg
# image data size -  240
# batch data -  57600
#     
2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  65   97  60  0
# 1  68  100  63  0
# 2  72  104  67  0
# 3  74  106  69  0
# 4  75  107  70  0
# Processed batch 191
# Yielded a batch of size 10
# Inside the listdir-  211654_ortho_1-1_1n_s_il113_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/211654_ortho_1-1_1n_s_il113_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  77  102  73  0
# 1  72   97  68  0
# 2  66   91  62  0
# 3  82  107  78  0
# 4  62   87  58  0
# Processed batch 192
# Yielded a batch of size 10
# Inside the listdir-  102336_ortho_1-1_1n_s_il037_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/102336_ortho_1-1_1n_s_il037_2017_1.jpg
# image data size -  240
# batch data -  57600
#      0    1    2  3
# 0  102  120   96  0
# 1  110  128  104  0
# 2  117  135  111  0
# 3  119  137  113  0
# 4  121  139  115  0
# Processed batch 193
# Yielded a batch of size 10
# Inside the listdir-  333078_ortho_1-1_1n_s_ia025_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/333078_ortho_1-1_1n_s_ia025_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  83  110  75  0
# 1  80  107  72  0
# 2  77  104  69  0
# 3  77  104  69  0
# 4  79  106  71  0
# Processed batch 194
# Yielded a batch of size 10
# Inside the listdir-  267610_ortho_1-1_1n_s_il179_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/267610_ortho_1-1_1n_s_il179_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  76  104  79  0
# 1  73  101  76  0
# 2  71   99  74  0
# 3  73  101  76  0
# 4  78  106  81  0
# Processed batch 195
# Yielded a batch of size 10
# Inside the listdir-  327010_ortho_1-1_1n_s_ia023_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/327010_ortho_1-1_1n_s_ia023_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0   1   2  3
# 0  79  91  69  0
# 1  79  91  69  0
# 2  79  91  69  0
# 3  80  92  70  0
# 4  80  92  70  0
# Processed batch 196
# Yielded a batch of size 10
# Inside the listdir-  178431_ortho_1-1_1n_s_il099_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/178431_ortho_1-1_1n_s_il099_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  74   92  70  0
# 1  66   84  62  0
# 2  80   95  74  0
# 3  75   88  68  0
# 4  93  102  83  0
# Processed batch 197
# Yielded a batch of size 10
# Inside the listdir-  543778_ortho_1-1_1n_s_ia177_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/543778_ortho_1-1_1n_s_ia177_2017_1.jpg
# image data size -  240
# batch data -  57600
#      0    1    2  3
# 0  141  121   94  0
# 1  131  111   84  0
# 2  141  121   94  0
# 3  135  118   90  0
# 4  155  138  110  0
# Processed batch 198
# Yielded a batch of size 10
# Inside the listdir-  402453_ortho_1-1_1n_s_ia069_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/402453_ortho_1-1_1n_s_ia069_2017_1.jpg
# image data size -  240
# batch data -  57600
#      0    1    2  3
# 0  102  127   97  0
# 1  107  132  102  0
# 2   99  124   94  0
# 3   94  119   89  0
# 4  102  127   97  0
# Processed batch 199
# Yielded a batch of size 10
# Inside the listdir-  191068_ortho_1-1_1n_s_il105_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/191068_ortho_1-1_1n_s_il105_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  77  101  67  0
# 1  84  108  76  0
# 2  89  112  83  0
# 3  89  109  84  0
# 4  85  105  80  0
# Processed batch 200
# Yielded a batch of size 10
# Inside the listdir-  90309_ortho_1-1_1n_s_il029_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/90309_ortho_1-1_1n_s_il029_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0   1   2  3
# 0  66  91  70  0
# 1  65  90  69  0
# 2  62  87  66  0
# 3  60  85  64  0
# 4  59  84  63  0
# Processed batch 201
# Yielded a batch of size 10
# Inside the listdir-  304753_ortho_1-1_1n_s_ia015_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/304753_ortho_1-1_1n_s_ia015_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  87  117  83  0
# 1  88  118  84  0
# 2  87  117  83  0
# 3  83  113  79  0
# 4  79  109  75  0
# Processed batch 202
# Yielded a batch of size 10
# Inside the listdir-  201940_ortho_1-1_1n_s_il109_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/201940_ortho_1-1_1n_s_il109_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  74  100  73  0
# 1  79  105  78  0
# 2  82  108  81  0
# 3  80  106  79  0
# 4  74  100  73  0
# Processed batch 203
# Yielded a batch of size 10
# Inside the listdir-  482429_ortho_1-1_1n_s_ia131_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/482429_ortho_1-1_1n_s_ia131_2017_1.jpg
# image data size -  240
# batch data -  57600
#      0    1   2  3
# 0  114  125  85  0
# 1  106  117  77  0
# 2  103  114  74  0
# 3  108  119  79  0
# 4  111  122  82  0
# Processed batch 204
# Yielded a batch of size 10
# Inside the listdir-  45621_ortho_1-1_1n_s_il007_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/45621_ortho_1-1_1n_s_il007_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  64  101  70  0
# 1  64  101  70  0
# 2  64  101  70  0
# 3  65  102  71  0
# 4  65  102  71  0
# Processed batch 205
# Yielded a batch of size 10
# Inside the listdir-  81278_ortho_1-1_1n_s_il021_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/81278_ortho_1-1_1n_s_il021_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  74  102  79  0
# 1  56   84  61  0
# 2  59   87  64  0
# 3  71   99  76  0
# 4  65   93  70  0
# Processed batch 206
# Yielded a batch of size 10
# Inside the listdir-  375447_ortho_1-1_1n_s_ia049_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/375447_ortho_1-1_1n_s_ia049_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0    1   2  3
# 0  76  105  77  0
# 1  80  109  81  0
# 2  70   99  71  0
# 3  78  107  79  0
# 4  80  109  81  0
# Processed batch 207
# Yielded a batch of size 10
# Inside the listdir-  301211_ortho_1-1_1n_s_ia013_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/301211_ortho_1-1_1n_s_ia013_2017_1.jpg
# image data size -  240
# batch data -  57600
#      0    1    2  3
# 0  171  154  138  0
# 1  164  147  131  0
# 2  161  144  128  0
# 3  165  148  132  0
# 4  167  150  134  0
# Processed batch 208
# Yielded a batch of size 10
# Inside the listdir-  402956_ortho_1-1_1n_s_ia069_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/402956_ortho_1-1_1n_s_ia069_2017_1.jpg
# image data size -  240
# batch data -  57600
#     0   1   2  3
# 0  66  87  72  0
# 1  65  86  71  0
# 2  69  90  75  0
# 3  73  94  79  0
# 4  70  91  76  0
# Processed batch 209
# Yielded a batch of size 10
# Inside the listdir-  128200_ortho_1-1_1n_s_il059_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/128200_ortho_1-1_1n_s_il059_2017_1.jpg
# image data size -  240
# batch data -  57600
#      0    1    2  3
# 0  146  143  110  0
# 1  138  135  102  0
# 2  134  131   98  0
# 3  137  134  101  0
# 4  138  135  102  0
# Processed batch 210
# Yielded a batch of size 10
# Inside the listdir-  241889_ortho_1-1_1n_s_il139_2017_1.jpg
# Image is valid jpg
# Reading image: /Users/c.himadry/Downloads/NAIP/test/0/241889_ortho_1-1_1n_s_il139_2017_1.jpg
# image data size -  240
# batch data -  57600

# %%
import pandas as pd

input_csv_path = '/Users/c.himadry/Desktop/crop_classification/dataset/image_data.csv'  # Path to your original large CSV file
output_csv_path = '/Users/c.himadry/Downloads/NAIP/image_data_processed.csv'  # Path for the new deduplicated CSV file

chunk_size = 10000  # Adjust this depending on your memory capacity
columns = None  # For storing column names

# Create an iterator to read the CSV file in chunks
reader = pd.read_csv(input_csv_path, chunksize=chunk_size)

# Process each chunk
for i, chunk in enumerate(reader):
    print(f"Processing chunk {i+1}")

    # Store column names from the first chunk
    if columns is None:
        columns = chunk.columns

    # Remove duplicate rows
    deduplicated_chunk = chunk.drop_duplicates()

    # Write the deduplicated chunk to a new CSV file
    if i == 0:
        # Write the first chunk with headers
        deduplicated_chunk.to_csv(output_csv_path, mode='w', index=False)
    else:
        # Append subsequent chunks without headers
        deduplicated_chunk.to_csv(output_csv_path, mode='a', index=False, header=False)

    print(f"Processed chunk {i+1}, {len(deduplicated_chunk)} rows written to CSV")

print("Processing completed. Deduplicated data saved to:", output_csv_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       7 columns = None  # For storing column names
#       9 # Create an iterator to read the CSV file in chunks
# ---> 10 reader = pd.read_csv(input_csv_path, chunksize=chunk_size)
#      12 # Process each chunk
#      13 for i, chunk in enumerate(reader):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/c.himadry/Desktop/crop_classification/dataset/image_data.csv'
